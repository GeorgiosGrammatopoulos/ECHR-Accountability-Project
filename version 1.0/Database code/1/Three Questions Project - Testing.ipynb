-- %%
---Test 1: 'Check' Constraints---

INSERT INTO [European Court of Human Rights]
    ([Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award])
VALUES ('Poland', 'Kamia', 'H skouriasmeni mpatania', '2', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 22000, 22000, 22000);

---Test 1.1: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award])
VALUES ('Poland', 'Kamia', 'H skouriasmeni mpatania', '2', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000);

---Test 1.2: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award])
VALUES ('Janowski','Zambia', 'Kamia', 'H skouriasmeni mpatania', '2', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000);

---Test 1.3: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Kamia', 'H skouriasmeni mpatania', '2', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.4: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.5: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.6: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, 'tits', 'tits', 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.7: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, 'tits', NULL, 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.8: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, NULL, NULL, 'tits', 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.9: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, NULL, NULL, NULL, 'tits', 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.10: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, NULL, NULL, NULL, NULL, 'tits', 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.11: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, 'tits', 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.12: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', 'H skouriasmeni mpatania', '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.13: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Zambia', 'Partial', NULL, '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.14: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Poland', 'Partial', NULL, '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 6, 22000, 22000, 22000, 0, 36710);

---Test 1.15: Check---

GO

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Claimed],
    [Material Damage Award],
    [Non-Material Damage Award],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Poland', 'Partial', NULL, '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 6, NULL, NULL, 22000, 22000, 0, 36710);

---Test 1.16: Check---

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Claimed],
    [Material Damage Award],
    [Non- Material Damage Claimed],
    [Non-Material Damage Award],
    [C&E Claimed],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Poland', 'Partial', NULL, '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 6, NULL, NULL, NULL, NULL, NULL, NULL, 0, 36710);

---Test 1.17: Check---

-- %%
---Test 1, continued---

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Political Dummy], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Claimed],
    [Material Damage Award],
    [Non- Material Damage Claimed],
    [Non-Material Damage Award],
    [C&E Claimed],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Poland', 'Partial', NULL, '2', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 5, NULL, NULL, NULL, NULL, NULL, NULL, 0, 36710);

---Test 1.18: Check---

-- %%
---Test 1 Results: Damage triggers not functional-rewrite. Test material damage clauses---

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Claimed],
    [Material Damage Award],
    [Non- Material Damage Claimed],
    [Non-Material Damage Award],
    [C&E Claimed],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('Janowski','Poland', 'Partial', NULL, 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 5, NULL, NULL, NULL, NULL, NULL, NULL, 0, 36710);

---Test 1.19: Check---

-- %%
---Test 2: 'Trigger' Constraints and table bindings---

INSERT INTO [Case Metadata] ([Case Name], [Application Date], [Decision Date], [Case Reference], [Footnote], [Link])
VALUES ('Janowski', '1998-02-26', '1999-01-21','Application no. 25716/94', 'Janowski v. Poland, App. No. 25716/94 [1999] Eur. Ct. H. R., https://hudoc.echr.coe.int/eng?i=001-58909', 'https://hudoc.echr.coe.int/eng?i=001-58909')

---Test 2: Check

-- %%
---Test 3: Second review of constraints and triggers---

INSERT INTO [Case Metadata] ([Case Name], [Application Date], [Decision Date], [Case Reference], [Footnote], [Link])
VALUES ('L.B.', '2017-06-07', '2023-03-09', 'Application no. 36345/16', 'L.B. v. Hungary, App. No. 36345/16 [2023] Eur. Ct. H. R., https://hudoc.echr.coe.int/eng?i=001-223675', 'https://hudoc.echr.coe.int/eng?i=001-223675')

INSERT INTO [European Court of Human Rights]
    ([Case Name],
    [Respondent], 
    [Reliance on Government Record], 
    [Political Incident], 
    [Preliminary Objections], 
    [Preliminary Factual Reasoning], 
    [Qualitative Factual Dispute],
    [Qualitative Factual Reasoning],
    [Quantitative Factual Dispute],
    [Quantitative Factual Reasoning],
    [C&E Factual Dispute],
    [C&E Factual Reasoning],
    [Votes],
    [Minority Votes],
    [Material Damage Claimed],
    [Material Damage Award],
    [Non- Material Damage Claimed],
    [Non-Material Damage Award],
    [C&E Claimed],
    [C&E Award],
    [Texts Alleged],
    [Articles Alleged])
VALUES ('L.B.','Hungary', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 12, 5, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL);

---Test Result: Check---
---Observations: I think I can add an autocomplete feature for the footnote. That, and create the basic stats table, with full dependency on the other tables---
